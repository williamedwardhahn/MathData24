# %% [markdown]
# <a href="https://colab.research.google.com/github/williamedwardhahn/MathData24/blob/main/MathData_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notes
#
# <img src="https://www.flbog.edu/wp-content/uploads/fau-masthead-1024x427-1.jpg" width=400>

# %% [markdown]
# <img src="https://cdn.sanity.io/images/oaglaatp/production/86a82e4fb0cc58a2d321c9a4a78533904964cd51-6119x3718.jpg" width = 400>

# %% [markdown]
# Example notes go here

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
print(total)
# Out:
# 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# 0.17922082634694414

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.67379912, 0.56659066, 0.90981668, 0.91002034, 0.4190531 ]])

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.67379912, 0.56659066, 0.90981668, 0.91002034, 0.4190531 ]]),
#  array([[0.66098159, 0.12171437, 0.01327397, 0.28128668, 0.39181035]]))

# %%
A = A.T
B = B.T

# %%
A,B
# Out:
# (array([[0.67379912],
#         [0.56659066],
#         [0.90981668],
#         [0.91002034],
#         [0.4190531 ]]),
#  array([[0.66098159],
#         [0.12171437],
#         [0.01327397],
#         [0.28128668],
#         [0.39181035]]))

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y,'g--')

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.36908663, 0.47256275, 0.73420396, ..., 0.15818063, 0.93089842,
#         0.71824422],
#        [0.40548575, 0.0661624 , 0.45579716, ..., 0.45814935, 0.20277896,
#         0.38002143],
#        [0.41070211, 0.41133799, 0.33795513, ..., 0.90641987, 0.42469009,
#         0.23222508],
#        ...,
#        [0.33338463, 0.32469007, 0.72306169, ..., 0.85718581, 0.13343114,
#         0.31127985],
#        [0.34304745, 0.14871359, 0.19361781, ..., 0.94525278, 0.32224502,
#         0.45270442],
#        [0.6014599 , 0.36027732, 0.28860015, ..., 0.51210253, 0.89478425,
#         0.91563538]])

# %%
plt.imshow(Z)

# %%
# Create a sample matrix (2D array)
matrix = np.array([[1, 2, 3, 4],
                   [15, 16, 27, 8],
                   [9, 10, 11, 12],
                   [13, 14, 15, 16]])

# Plot the matrix
plt.imshow(matrix, cmap='Blues')
